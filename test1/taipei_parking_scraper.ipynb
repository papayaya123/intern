# %% [markdown]
# #### Taipei Parking Scraper

# %%
# === Imports ===
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, parse_qs, urlencode, urlunparse
import csv
import sys

# Optional: pandas for convenient CSV export / preview
try:
    import pandas as pd
except Exception:
    pd = None

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Accept-Language": "zh-TW,zh;q=0.9,en;q=0.8",
}
TIMEOUT = 20

# %%
# === Parameters ===
# 你可以在這裡更改要抓取的頁面與 PageSize
URL = "https://pma.gov.taipei/News.aspx?n=6833ECE829BE5990&sms=504AB58CAE8A1C62&page=17&PageSize=337"

# 輸出的檔名
OUTPUT_CSV = "taipei_parking_page17.csv"

# %%
# === Helper Functions ===
def fetch_soup(url: str) -> BeautifulSoup:
    """抓取並回傳 BeautifulSoup 物件。"""
    r = requests.get(url, headers=HEADERS, timeout=TIMEOUT)
    r.raise_for_status()
    return BeautifulSoup(r.text, "html.parser")

def norm(txt: str) -> str:
    """去除多餘空白與全形空白。"""
    return (txt or "").replace("\xa0", " ").replace("\u3000", " ").strip()

def extract_rows(soup: BeautifulSoup):
    """
    逐列把 <td data-title="欄名">值</td> 組成 dict。
    這頁的 <td> 都有 data-title，所以用它來定位欄位最保險。
    只保留有「停車場名稱」的列。
    """
    rows = []
    # 掃所有 tbody（有時頁面不只一個表）
    for tbody in soup.find_all("tbody"):
        for tr in tbody.find_all("tr"):
            tds = tr.find_all("td")
            if not tds:
                continue
            row = {}
            for td in tds:
                key = norm(td.get("data-title") or "")
                if not key:
                    continue
                val = norm(td.get_text(" ", strip=True))
                row[key] = val
            if row.get("停車場名稱"):
                rows.append(row)
    return rows

# %%
# === Field Mapping ===
KEYMAP = {
    "name":      ["停車場名稱"],
    "rate":      ["費率", "收費標準"],
    "address":   ["停車場地址", "地址"],
    "phone":     ["停車場電話", "電話", "聯絡電話"],
    "open_time": ["開放時間", "營業時間", "開放時段"],
    "car_spaces": ["小車", "小型車", "小客車"],
    "moto_spaces": ["機車", "機車位"],
    "truck_spaces": ["大車", "大客車", "大貨車"],
    "district": ["行政區"],
    "type": ["停車場位置點"],
}

def pick(row: dict, keys: list):
    for k in keys:
        if k in row and row[k] != "":
            return row[k]
    return ""

def map_fields(row: dict) -> dict:
    return {
        "停車場名稱": pick(row, KEYMAP["name"]),
        "費率": pick(row, KEYMAP["rate"]),
        "停車場地址": pick(row, KEYMAP["address"]),
        "電話": pick(row, KEYMAP["phone"]),
        "開放時間": pick(row, KEYMAP["open_time"]),
        "汽車車位數": pick(row, KEYMAP["car_spaces"]),
        "機車車位數": pick(row, KEYMAP["moto_spaces"]),
        "大車車位數": pick(row, KEYMAP["truck_spaces"]),
        "行政區": pick(row, KEYMAP["district"]),
        "位置型態": pick(row, KEYMAP["type"]),
    }

# %%
# === Save CSV ===
def save_csv(records, path="taipei_parking_page17.csv"):
    """優先用 pandas；若無則退回內建 csv。"""
    if not records:
        print("沒有可儲存的資料。")
        return

    if pd is not None:
        df = pd.DataFrame(records)
        df.to_csv(path, index=False, encoding="utf-8")
        print(f"已輸出 CSV：{path}（使用 pandas）")
    else:
        cols = list(records[0].keys())
        with open(path, "w", newline="", encoding="utf-8") as f:
            w = csv.DictWriter(f, fieldnames=cols)
            w.writeheader()
            for r in records:
                w.writerow(r)
        print(f"已輸出 CSV：{path}（使用內建 csv）")

# %%
# === Run ===
# 抓取與解析
soup = fetch_soup(URL)
raw_rows = extract_rows(soup)

# 欄位正規化
data = [map_fields(r) for r in raw_rows]

# 檢視前幾筆
for i, row in enumerate(data[:5], 1):
    preview = [
        row.get('停車場名稱', ''),
        row.get('行政區', ''),
        row.get('停車場地址', ''),
        f"小車:{row.get('汽車車位數', '')} 機車:{row.get('機車車位數', '')}",
        row.get('費率', ''),
        row.get('開放時間', ''),
        row.get('電話', ''),
    ]
    print(f"[{i}] " + "｜".join(map(str, preview)))

print("總筆數：", len(data))
# Out:
# [1] 遼寧街185巷機車平面停車場｜臺北市中山區｜遼寧街185巷17號對面｜小車: 機車:35｜計次20元(凡跨越每日零時起重行起算)｜9-17｜
# [2] 大業路527巷平面停車場｜臺北市北投區｜大業路527巷近捷運復興崗站｜小車:14 機車:10｜小型車計次50元，機車免費。｜9-17｜
# [3] 平陽街18號機車平面停車場｜臺北市大同區｜平陽街18號旁｜小車: 機車:23｜計時10元，當日當次最高上限30元(隔日另計)。｜9-20｜
# [4] 中華路二段409巷平面停車場｜臺北市中正區｜中華路2段409巷1號對面｜小車:5 機車:｜計時30元｜9-17｜
# [5] 南港公園平面停車場｜臺北市南港區｜東新街170號(南港公園大門旁)｜小車:84 機車:｜計時20元｜24小時｜29441489
# 總筆數： 337

# %%
# === Save to CSV ===
save_csv(data, OUTPUT_CSV)
# Out:
# 已輸出 CSV：taipei_parking_page17.csv（使用 pandas）

# %%
import requests

PLACES_URL = "https://maps.googleapis.com/maps/api/place/textsearch/json"

def get_lat_lng_place(query, api_key):
    params = {
        "query": query,
        "key": api_key,
        "language": "zh-TW",  # 回傳繁體中文
        "region": "tw"        # 偏向台灣地區
    }
    r = requests.get(PLACES_URL, params=params, timeout=10)
    data = r.json()
    
    if data.get("status") == "OK" and data.get("results"):
        loc = data["results"][0]["geometry"]["location"]
        return loc["lat"], loc["lng"]
    else:
        raise RuntimeError(f"查詢失敗：{data.get('status')} - {data.get('error_message')}")

# === 測試 ===
with open("api.txt", "r", encoding="utf-8") as f:
    api_key = f.read().strip()

query = "重新家樂福 12mini"
try:
    lat, lng = get_lat_lng_place(query, api_key)
    print(f"經緯度：{lat}, {lng}")
except Exception as e:
    print("查詢失敗：", e)
# Out:
# 經緯度：25.0431845, 121.4678297

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('taipei_parking_page17.csv')


# 先新增空欄位，先放 NaN
df["latitude"] = np.nan
df["longitude"] = np.nan

for idx, row in df.iterrows():
    name = row["停車場名稱"]
    try:
        lat, lng = get_lat_lng_place(name, api_key)
        # 存回 DataFrame
        df.at[idx, "latitude"] = lat
        df.at[idx, "longitude"] = lng
        print(f"{name} → 經緯度：{lat}, {lng}")
    except Exception as e:
        print(f"{name} 查詢失敗：{e}")
# Out:
# 遼寧街185巷機車平面停車場 → 經緯度：25.0537072, 121.5427812
# 大業路527巷平面停車場 → 經緯度：25.1356749, 121.4946365
# 平陽街18號機車平面停車場 → 經緯度：22.6406602, 120.3072516
# 中華路二段409巷平面停車場 → 經緯度：22.7259484, 120.3525723
# 南港公園平面停車場 → 經緯度：25.0457639, 121.5913917
# 洲美公園臨時平面停車場 → 經緯度：25.1002147, 121.505771
# 北投製片廠平面停車場 → 經緯度：25.1397346, 121.487086
# 內湖國中地下停車場 → 經緯度：25.0770945, 121.5891588
# 文林橋下平面停車場 → 經緯度：25.101787, 121.5166173
# 民權東路3段153巷西側平面停車場 → 經緯度：25.062314, 121.5464542
# 民權東路3段197巷口東側平面停車場 → 經緯度：25.062314, 121.5464542
# 三合街1段82巷62弄平面停車場 → 經緯度：25.1279102, 121.5053116
# 三合街1段82巷86弄平面停車場 → 經緯度：25.1279102, 121.5053116
# 興隆A區社會住宅地下停車場 → 經緯度：24.9881558, 121.5625456
# 興德路62巷平面停車場 → 經緯度：25.000642, 121.551241
# 大安國中地下停車場 → 經緯度：25.0299188, 121.5461616
# 環南堤外平面停車場 → 經緯度：25.0288489, 121.4880539
# 杭州南路2段51巷平面停車場 → 經緯度：25.0329663, 121.5232941
# 廣慈3區社會住宅地下停車場 → 經緯度：25.0392794, 121.5828103
# 吳興街220巷59弄平面停車場 → 經緯度：25.0268659, 121.5604614
# 臨沂街71巷平面停車場 → 經緯度：25.036734, 121.5288569
# 福國路(洲美段二)橋下平面停車場 → 經緯度：25.1207239, 121.4990794
# 民權東路三段197巷口西側平面停車場 → 經緯度：25.062314, 121.5464542
# 青年二期社會住宅地下停車場 → 經緯度：25.0204879, 121.5033358
# 和興水岸社會住宅地下停車場 → 經緯度：24.9850552, 121.5493036
# 辛亥生態公園平面停車場 → 經緯度：25.0035071, 121.5567258
# 辛亥路一段100號機車停車場 → 經緯度：25.02157, 121.5317156
# 木柵路三段48巷平面停車場 → 經緯度：24.9892213, 121.5670403
# 仁愛路4段512巷機車平面停車場 → 經緯度：25.0369838, 121.5612802
# 福星社會住宅地下停車場 → 經緯度：25.0471312, 121.506194
# 溫州街52巷平面停車場 → 經緯度：25.0210657, 121.5329239
# 捷運劍潭站橋下機車停車場 → 經緯度：25.0865038, 121.5258885
# 捷運士林站橋下機車停車場 → 經緯度：25.0900792, 121.5272275
# 舊莊街1段3巷平面停車場 → 經緯度：25.0409614, 121.6203977
# 木柵路三段平面停車場 → 經緯度：25.2062149, 121.4491694
# 湖畔公園平面停車場 → 經緯度：22.889194, 120.478159
# 臺北大橋橋下機車停車場 → 經緯度：25.063125, 121.509893
# 東湖立體停車場 → 經緯度：25.0692881, 121.6124106
# 新和國小地下停車場 → 經緯度：25.0266657, 121.5027591
# 福國路(洲美段一)橋下平面停車場 → 經緯度：25.1207239, 121.4990794
# 民權西路160巷機車平面停車場 → 經緯度：25.0628548, 121.5155311
# 昆陽站旁機車平面停車場 → 經緯度：25.050735, 121.594485
# 景美女中地下停車場 → 經緯度：24.9820431, 121.5565877
# 中山國中地下停車場 → 經緯度：25.0606557, 121.5464855
# 莒光社會住宅地下停車場 → 經緯度：25.0319313, 121.4998467
# 龍江路229巷臨時平面停車場 → 經緯度：25.0572027, 121.5418829
# 信義路3段134巷臨時平面停車場 → 經緯度：25.0324326, 121.5398011
# 行善社會住宅地下停車場 → 經緯度：25.0610715, 121.5820526
# 廣慈衛福大樓地下停車場 → 經緯度：25.0386393, 121.5831563
# 信義區行政中心地下停車場 → 經緯度：25.0330535, 121.5663935
# 金湖臨時平面停車場(二) → 經緯度：25.0810604, 121.5980114
# 民族西路303巷臨時平面停車場 → 經緯度：25.0698998, 121.5103769
# 興旺平面停車場 → 經緯度：22.6159886, 120.3053798
# 三合街一段82巷平面停車場 → 經緯度：25.1279102, 121.5053116
# 廣慈社會住宅2區地下停車場 → 經緯度：25.0392794, 121.5828103
# 新新公園平面停車場 → 經緯度：25.0512578, 121.5906375
# 廣慈社會住宅1區地下停車場 → 經緯度：25.0392794, 121.5828103
# 忠義站平面停車場 → 經緯度：25.1310564, 121.4731885
# 小彎社會住宅地下停車場 → 經緯度：25.0577713, 121.593463
# 新和庭園平面停車場 → 經緯度：25.0278959, 121.5051108
# 信安街67巷臨時平面停車場 → 經緯度：25.0258195, 121.5593744
# 基河路大客車平面停車場 → 經緯度：25.0950685, 121.5187885
# 延平北路2段247巷機車平面停車場 → 經緯度：25.0564666, 121.5109837
# 和興路53巷臨時平面停車場 → 經緯度：24.9963529, 121.5457746
# 豐年運動公園(一)平面停車場 → 經緯度：25.1356749, 121.4946365
# 豐年運動公園平面停車場 → 經緯度：25.1356749, 121.4946365
# 仁愛路4段496巷臨時平面停車場 → 經緯度：25.0324326, 121.5398011
# 羅斯福路5段236巷臨時平面停車場 → 經緯度：25.0025345, 121.5446868
# 健康2區社會住宅地下停車場 → 經緯度：25.0545688, 121.5641998
# 健康1區社會住宅地下停車場 → 經緯度：25.0545688, 121.5641998
# 青年一期社會住宅地下停車場 → 經緯度：25.0202393, 121.5036784
# 東明公共住宅乙區地下停車場 → 經緯度：25.0544647, 121.6041516
# 東明公共住宅甲區地下停車場 → 經緯度：25.0545217, 121.6038509
# 興隆公共住宅D1區地下停車場 → 經緯度：24.9883698, 121.5579955
# 大港墘公園大客車平面停車場 → 經緯度：25.0784192, 121.5743909
# 大港墘公園地下停車場 → 經緯度：25.0784192, 121.5743909
# 新奇岩社會住宅地下停車場 → 經緯度：25.1236578, 121.5034609
# 中南社會住宅地下停車場 → 經緯度：25.0429579, 121.6190295
# 社子大橋堤外平面停車場 → 經緯度：25.090703, 121.511976
# 瑞光社會住宅地下停車場 → 經緯度：25.073129, 121.578895
# 明倫社會住宅地下停車場 → 經緯度：25.0728051, 121.5198969
# 木柵社會住宅地下停車場 → 經緯度：24.989228, 121.566365
# 懷德街55巷平面停車場 → 經緯度：25.1129707, 121.5189304
# 安康公園臨時平面停車場 → 經緯度：25.0674808, 121.6133746
# 延平國小地下停車場 → 經緯度：25.0671671, 121.5119117
# 興德路臨時平面停車場 → 經緯度：24.9963529, 121.5457746
# 華中橋堤外(二)停車場 → 經緯度：25.0197214, 121.4923022
# 萬華車站地下停車場 → 經緯度：25.0334845, 121.4994222
# 景興路臨時平面停車場 → 經緯度：24.9963529, 121.5457746
# 興隆路三段229巷平面停車場 → 經緯度：24.9929821, 121.5595668
# 大坑街臨時平面停車場 → 經緯度：24.9550571, 121.496649
# 辛亥路溫州段橋下平面停車場 → 經緯度：25.0225851, 121.5336397
# 萬寧街臨時平面停車場 → 經緯度：22.9339916, 120.1885314
# 基隆河大佳網球場平面停車場 → 經緯度：25.0747884, 121.5315181
# 永春陂濕地公園平面停車場 → 經緯度：25.032531, 121.5800718
# 景勤二號公園地下停車場 → 經緯度：25.0260548, 121.5585051
# 成功路5段120巷臨時平面停車場 → 經緯度：22.594997, 120.3047528
# 秀山國小臨時平面停車場 → 經緯度：24.9908492, 121.5243298
# 臨沂街臨時平面停車場(二) → 經緯度：25.0367394, 121.5287874
# 安康平宅B臨時平面停車場 → 經緯度：25.0674808, 121.6133746
# 新生公園停車場 → 經緯度：25.0685358, 121.5310516
# 福林路大客車平面停車場 → 經緯度：25.0967335, 121.5332541
# 百齡橋堤外足球場停車場(二) → 經緯度：25.0870995, 121.5153072
# 內湖污水處理廠附屬公園停車場 → 經緯度：25.0663885, 121.5744397
# 安康平宅臨時平面停車場 → 經緯度：24.9550571, 121.496649
# 興隆D2區公共住宅地下停車場 → 經緯度：24.9881558, 121.5625456
# 木柵路三段77巷臨時平面停車場 → 經緯度：24.9892213, 121.5670403
# 公舘路228巷臨時平面停車場 → 經緯度：25.1211599, 121.5032794
# 長春路龍江路臨時平面停車場 → 經緯度：25.054823, 121.5400626
# 客委會臨時平面停車場 → 經緯度：25.0343142, 121.5430887
# 永建國小地下停車場 → 經緯度：24.9893389, 121.5559637
# 五常街臨時平面停車場 → 經緯度：25.0644107, 121.5422141
# 洲美快速道路橋下平面停車場 → 經緯度：25.1207239, 121.4990794
# 正氣橋下平面停車場 → 經緯度：25.0481214, 121.5684421
# 信義路5段150巷臨時平面停車場 → 經緯度：25.025819, 121.570518
# 八德立體停車場 → 經緯度：25.0495736, 121.5717127
# 康樂合署大樓地下停車場 → 經緯度：25.0724427, 121.6190639
# 福國路橋下平面停車場 → 經緯度：25.101917, 121.518165
# 新生北路2段77巷臨時平面停車場 → 經緯度：25.0461728, 121.5320562
# 雙園堤外平面停車場 → 經緯度：25.0326759, 121.4875989
# 長春路平面停車場 → 經緯度：25.0544095, 121.5265617
# 木柵公園平面停車場 → 經緯度：24.9867831, 121.5606149
# 行一機車臨時平面停車場 → 經緯度：25.0477223, 121.5209023
# 光復北路平面停車場 → 經緯度：25.0503072, 121.5611456
# 臨沂街臨時平面停車場(一) → 經緯度：25.0418097, 121.530815
# 臨沂街臨時平面停車場 → 經緯度：25.0418097, 121.530815
# 建國南路高架橋下停車場(濟南路-和平東路) → 經緯度：25.029025, 121.5377204
# 長安東路臨時平面停車場(一) → 經緯度：25.0472037, 121.5294701
# 大業路280巷臨時平面停車場 → 經緯度：25.1292414, 121.4977946
# 昆陽捷運站旁平面停車場 → 經緯度：25.050735, 121.594485
# 彩虹河濱公園堤外停車場 → 經緯度：25.0595557, 121.5727796
# 福林路平面停車場 → 經緯度：25.0964436, 121.5331831
# 建國北路高架橋下停車場(八德路-民族東路) → 經緯度：25.065938, 121.5361529
# 百齡橋堤外足球場停車場(一) → 經緯度：25.090703, 121.511976
# 啟聰學校地下停車場 → 經緯度：25.0743418, 121.5117964
# 嘉興公園地下停車場 → 經緯度：25.021666, 121.551928
# 莒光立體停車場 → 經緯度：25.0311115, 121.5034169
# 松山國小地下停車場 → 經緯度：25.0502303, 121.5785915
# 信義路5段150巷平面停車場 → 經緯度：25.025661, 121.570594
# 通河西街一段堤外平面停車場 → 經緯度：25.0837611, 121.5133055
# 福林公園大客車停車場 → 經緯度：25.0967335, 121.5332541
# 福林公園地下停車場 → 經緯度：25.095975, 121.5307189
# 松山車站地下停車場 → 經緯度：25.0482556, 121.5784564
# 松山工農地下停車場 → 經緯度：25.03904, 121.5724243
# 撫遠平面停車場 → 經緯度：25.067771, 121.567004
# 萬興國小地下停車場 → 經緯度：24.9894653, 121.5767155
# 世貿公園地下停車場 → 經緯度：25.0578528, 121.6145904
# 大龍國小地下停車場 → 經緯度：25.074126, 121.517292
# 建成公園地下停車場 → 經緯度：25.050566, 121.5196283
# 蘭雅公園地下停車場 → 經緯度：25.10955, 121.5293223
# 信義國小地下停車場 → 經緯度：25.0319319, 121.562621
# 至善公園平面停車場 → 經緯度：25.0981985, 121.5383117
# 基隆河濱公園迎風段(一) → 經緯度：25.074188, 121.547043
# 基隆河大佳段河濱公園停車場 → 經緯度：25.073772, 121.5409629
# 兒童育樂中心平面停車場 → 經緯度：25.0749846, 121.5215023
# 基隆河迎風段河濱公園停車場 → 經緯度：25.0734815, 121.5546443
# 敦煌路大型車平面停車場 → 經緯度：25.0768037, 121.5173357
# 行一大客車平面停車場 → 經緯度：25.0474808, 121.5219074
# 承德橋下停車場 → 經緯度：25.0777125, 121.5188136
# 西湖公園地下停車場 → 經緯度：25.0842354, 121.5705822
# 中山南路2巷臨時平面停車場 → 經緯度：25.0454826, 121.5176188
# 玉成公園地下停車場 → 經緯度：25.042201, 121.5871481
# 吳興街220巷平面停車場 → 經緯度：25.0255973, 121.5597537
# 蓬萊國小地下停車場 → 經緯度：25.0554429, 121.5155291
# 臺北製糖所文化園區地下停車場 → 經緯度：25.0334802, 121.4941559
# 南港國小地下停車場 → 經緯度：25.0564874, 121.611225
# 臺北大橋橋下停車場 → 經緯度：25.063125, 121.509893
# 遼寧街199巷17號機車平面停車場 → 經緯度：25.0539739, 121.5427937
# 遼寧街185巷7弄機車平面停車場 → 經緯度：25.0537072, 121.5427812
# 承德公園地下停車場 → 經緯度：25.0898301, 121.52216
# 社子國小地下停車場 → 經緯度：25.0913507, 121.5022075
# 吉祥平面停車場 → 經緯度：25.0503072, 121.5611456
# 民生社區中心地下停車場 → 經緯度：25.0597632, 121.5630115
# 忠誠路(二)平面停車場 → 經緯度：25.1068355, 121.5293631
# 北寧路地下停車場 → 經緯度：25.0491787, 121.5525445
# 政大三街臨時平面停車場 → 經緯度：24.9861571, 121.5830674
# 忠誠路(一)平面停車場 → 經緯度：25.1075262, 121.5297247
# 辛亥路高架橋下停車場 → 經緯度：25.0140687, 121.5532205
# 陽明山立體停車場 → 經緯度：25.1546396, 121.5390082
# 故宮廣場停車場 → 經緯度：25.09907, 121.5492978
# 陽明山花鐘停車場 → 經緯度：25.1578148, 121.539323
# 陽明山第二停車場 → 經緯度：25.1553129, 121.5458586
# 雅祥公園地下停車場 → 經緯度：25.047512, 121.571726
# 景美國小地下停車場 → 經緯度：24.9885387, 121.5402222
# 玉成國小地下停車場 → 經緯度：25.0532036, 121.5927067
# 興隆公園地下停車場 → 經緯度：25.000642, 121.551241
# 西康地下停車場 → 經緯度：25.0847037, 121.563676
# 立農公園地下停車場 → 經緯度：25.1185306, 121.5030468
# 松隆平面停車場 → 經緯度：25.0484348, 121.5755177
# 金湖臨時平面停車場 → 經緯度：25.0814273, 121.5980278
# 公舘路平面停車場 → 經緯度：25.1211599, 121.5032794
# 大湖公園地下停車場 → 經緯度：25.0835653, 121.6020551
# 萬華國中地下停車場 → 經緯度：25.0291748, 121.4995653
# 洛陽綜合立體停車場 → 經緯度：25.0475578, 121.5051561
# 松壽廣場地下停車場 → 經緯度：25.0370551, 121.5664353
# 松山高中地下停車場 → 經緯度：25.044065, 121.5637821
# 市民大道(塔城段) → 經緯度：25.0503735, 121.5098014
# 市民大道(公中段) → 經緯度：25.0485232, 121.5181231
# 忠信地下停車場 → 經緯度：25.0402299, 121.5681927
# 建成國中地下停車場 → 經緯度：25.050566, 121.5196283
# 萬板地下停車場 → 經緯度：25.0282944, 121.4903048
# 信義廣場地下停車場 → 經緯度：25.0339469, 121.5665977
# 濱江國中地下停車場 → 經緯度：25.0794297, 121.5616506
# 三號水門堤外停車場 → 經緯度：25.0520548, 121.5067831
# 雙園平面停車場 → 經緯度：25.0326759, 121.4875989
# 福港街平面停車場 → 經緯度：25.0873563, 121.5185658
# 水源快速道路高架橋下 → 經緯度：25.0038588, 121.5353526
# 濱江橋下平面停車場 → 經緯度：25.0722922, 121.5415987
# 復興路平面停車場 → 經緯度：22.6107345, 120.310603
# 開勝平面停車場 → 經緯度：25.1407227, 121.5049463
# 東和平面停車場 → 經緯度：25.1202282, 121.5331748
# 三腳渡平面停車場 → 經緯度：25.0818385, 121.5163917
# 南港59號公園臨時平面停車場 → 經緯度：25.047531, 121.613505
# 七星公園地下停車場 → 經緯度：25.1365371, 121.5021269
# 峨眉立體停車場 → 經緯度：25.044291, 121.5057097
# 中山堂地下停車場 → 經緯度：25.0440657, 121.5105798
# 民生立體停車場 → 經緯度：25.0584097, 121.5596161
# 塔城公園地下停車場 → 經緯度：25.0508763, 121.5105798
# 百齡高中地下停車場 → 經緯度：25.0858255, 121.5236968
# 前港公園地下停車場 → 經緯度：25.0856274, 121.5209054
# 五分埔公園地下停車場 → 經緯度：25.0468265, 121.5805361
# 民權公園地下停車場 → 經緯度：25.06203, 121.5588489
# 金華公園地下停車場 → 經緯度：25.0296371, 121.5316137
# 古亭國中地下停車場 → 經緯度：25.0238805, 121.510034
# 景華公園地下停車場 → 經緯度：24.9951619, 121.5437724
# 大安森林公園地下停車場 → 經緯度：25.0318211, 121.5374572
# 市民大道(中林段) → 經緯度：25.047956, 121.5222903
# 市民大道(林金段) → 經緯度：25.0476593, 121.5255722
# 市民大道(建復段) → 經緯度：25.0447372, 121.5404601
# 大安高工地下停車場 → 經緯度：25.0326427, 121.5409407
# 大稻埕公園地下停車場 → 經緯度：25.0584443, 121.5105378
# 附中公園地下停車場 → 經緯度：25.036213, 121.5425902
# 興雅國中地下停車場 → 經緯度：25.0348228, 121.5727992
# 西松高中地下停車場 → 經緯度：25.0558398, 121.5660926
# 進安公園地下停車場 → 經緯度：25.0461441, 121.5377069
# 辛亥國小地下停車場 → 經緯度：25.0059885, 121.5584061
# 府前廣場地下停車場 → 經緯度：25.0359834, 121.5630113
# 成德立體停車場(機械) → 經緯度：25.0458579, 121.5860202
# 市民大道(復敦段) → 經緯度：25.0449666, 121.5473897
# 成淵高中地下停車場 → 經緯度：25.0603782, 121.5200647
# 大豐公園地下停車場 → 經緯度：25.1310894, 121.5042121
# 市民大道(敦延段) → 經緯度：25.0447489, 121.550675
# 市民大道(延吉段) → 經緯度：25.044458, 121.552122
# 健康國小地下停車場 → 經緯度：25.0562441, 121.5628404
# 興中立體停車場 → 經緯度：25.0560795, 121.6064258
# 社園立體停車場(機械) → 經緯度：25.0895898, 121.5059454
# 青年公園高爾夫球場地下停車場 → 經緯度：25.0243329, 121.5075346
# 揚雅立體停車場(機械) → 經緯度：25.0674314, 121.5158692
# 雙園國中地下停車場 → 經緯度：25.0277627, 121.4915469
# 東湖國小地下停車場 → 經緯度：25.0684371, 121.616062
# 文昌國小地下停車場 → 經緯度：25.0993119, 121.5219335
# 青年公園棒球場地下停車場 → 經緯度：25.023415, 121.5029778
# 林森公園地下停車場 → 經緯度：25.0523995, 121.5264481
# 偶戲博物館地下停車場 → 經緯度：25.04754, 121.5618884
# 中崙高中地下停車場 → 經緯度：25.0500922, 121.5613152
# 朝陽公園地下停車場 → 經緯度：25.0561166, 121.5137267
# 臺北花木批發市場地下停車場 → 經緯度：25.0045263, 121.5404497
# 永盛公園地下停車場 → 經緯度：25.0592421, 121.5247468
# 春光公園地下停車場 → 經緯度：25.0425178, 121.5810047
# 龍門國中地下停車場 → 經緯度：25.0237532, 121.5382271
# 艋舺公園地下停車場 → 經緯度：25.03615, 121.499496
# 振興公園地下停車場 → 經緯度：25.1187915, 121.5232622
# 民有市場地下停車場 → 經緯度：25.0604839, 121.5470182
# 麗湖國小地下停車場 → 經緯度：25.0731747, 121.6015065
# 三張里地下停車場 → 經緯度：25.0305704, 121.5669333
# 石牌國小地下停車場 → 經緯度：25.114495, 121.5131654
# 海光公園地下停車場 → 經緯度：25.081336, 121.5083568
# 港富立體停車場(機械) → 經緯度：25.080523, 121.5783648
# 康樂立體停車場(機械) → 經緯度：25.0719653, 121.6191366
# 臺北市災害應變中心地下停車場 → 經緯度：25.0288456, 121.5661533
# 長安國小地下停車場 → 經緯度：25.0503945, 121.5313703
# 湖興立體停車場 → 經緯度：25.0678426, 121.5904543
# 榮星花園地下停車場 → 經緯度：25.0641997, 121.5382948
# 僑安地下停車場 → 經緯度：25.0406905, 121.5566716
# 大業立體停車場(機械) → 經緯度：22.64748, 120.3255547
# 慶昌橋下停車場 → 經緯度：25.0763044, 121.5154936
# 五號水門堤外停車場 → 經緯度：25.0564523, 121.5078529
# 興隆市場旁停車場 → 經緯度：25.000642, 121.551241
# 新生北路高架橋下停車場 → 經緯度：25.0605135, 121.5277302
# 延吉廢鐵道停車場 → 經緯度：25.0434843, 121.5552033
# 桂林路底堤外停車場 → 經緯度：25.0390474, 121.4958233
# 建國南路高架橋下停車場(忠孝東路-建國南路175巷) → 經緯度：25.036877, 121.5376868
# 景文平面停車場 → 經緯度：24.9904812, 121.5404782
# 中山北路3段55巷停車場 → 經緯度：25.0680047, 121.5243318
# 三福街平面停車場 → 經緯度：25.014993, 121.4074633
# 四維廣場 → 經緯度：25.0873027, 121.4658371
# 龍江平面停車場 → 經緯度：22.6440086, 120.3094735
# 社中街平面停車場 → 經緯度：25.0896315, 121.5105429
# 耕莘文教院前平面停車場 → 經緯度：25.0190441, 121.5285084
# 溪洲街平面停車場 → 經緯度：25.0043711, 121.5354033
# 天母公園平面停車場 → 經緯度：25.125484, 121.5308349
# 研究院路平面停車場 → 經緯度：25.0449104, 121.6148511
# 社正路平面停車場 → 經緯度：25.0881171, 121.5090626
# 美德街平面停車場 → 經緯度：25.0970695, 121.5247804
# 永吉路120巷平面 → 經緯度：25.044657, 121.5697167
# 華江橋下雙層停車場 → 經緯度：25.0354566, 121.491488
# 行義路平面停車場 → 經緯度：25.123776, 121.526164
# 萬慶街平面停車場 → 經緯度：24.9937025, 121.5380902
# 中央北路四段平面停車場 → 經緯度：25.1281014, 121.4677027
# 永建市場旁平面停車場 → 經緯度：24.9881454, 121.551386
# 保儀路平面停車場 → 經緯度：24.9842647, 121.5663107
# 關渡醫院旁平面停車場 → 經緯度：25.1204055, 121.4657775
# 和平東路4段381巷平面停車場 → 經緯度：24.9995226, 121.5743621
# 文湖平面停車場 → 經緯度：25.0864377, 121.5607307
# 康寧平面停車場 → 經緯度：25.0761985, 121.6087901
# 石潭平面停車場 → 經緯度：25.0676721, 121.5928879
# 環山平面停車場 → 經緯度：25.0858262, 121.5721089
# 華江橋下停車場 → 經緯度：25.0354566, 121.491488
# 百齡橋堤外平面停車場 → 經緯度：25.0909485, 121.5118417
# 劍潭抽水站堤外平面停車場 → 經緯度：25.0798541, 121.5185344
# 松德臨時平面停車場 → 經緯度：25.0314969, 121.5735052
# 福山平面停車場 → 經緯度：25.0455653, 121.6156736
# 和興路平面停車場 → 經緯度：24.9851017, 121.5476457
# 至誠平面停車場 → 經緯度：25.1018877, 121.5314453
# 萬芳八號公園停車場 → 經緯度：25.0030411, 121.5606667
# 百齡橋堤外槌球場南側臨時平面停車場 → 經緯度：25.090703, 121.511976
# 華陰街臨時平面停車場 → 經緯度：25.0491426, 121.5203367
# 迪化污水處理場平面 → 經緯度：25.0733106, 121.5103484
# 安康公車調度站臨時平面 → 經緯度：25.0674808, 121.6133746
# 關渡水岸自然公園平面停車場 → 經緯度：25.1174757, 121.462997
# 吳興街284巷臨時平面停車場 → 經緯度：25.0255973, 121.5597537
# 雙溪公園平面停車場 → 經緯度：25.0979959, 121.5372193
# 明德臨時平面停車場 → 經緯度：22.6301711, 120.3276363
# 中山北路2段42巷臨時平面停車場 → 經緯度：25.0546022, 121.5213276
# 樂群臨時平面停車場 → 經緯度：25.0825264, 121.559144
# 同安街平面停車場 → 經緯度：25.0208203, 121.5208204
# 基隆河5、6號水門堤外觀山段河濱公園附設平面停車場 → 經緯度：25.065432, 121.568372
# 基隆河美堤段河濱公園附設平面停車場 → 經緯度：25.0581718, 121.569426
# 延平北路5段1巷平面停車場 → 經緯度：25.078792, 121.509777
# 百齡橋堤外(一)平面停車場 → 經緯度：25.0926844, 121.5103415
# 樟新平面停車場 → 經緯度：24.9795335, 121.5568719
# 中山運動中心旁平面停車場 → 經緯度：25.0547352, 121.5216194
# 景豐臨時平面停車場 → 經緯度：25.0025345, 121.5446868
# 華中橋堤外(一)平面停車場 → 經緯度：25.0170645, 121.4924857
# 洲子立體停車場 → 經緯度：25.0792778, 121.5694361
# 安祥公園旁平面停車場 → 經緯度：25.0342902, 121.5428143
# 洲美快速道路高架橋下平面停車場 → 經緯度：25.1207239, 121.4990794

# %%
df.to_csv("taipei_parking_with_lan.csv", index=False, encoding="utf-8-sig")
